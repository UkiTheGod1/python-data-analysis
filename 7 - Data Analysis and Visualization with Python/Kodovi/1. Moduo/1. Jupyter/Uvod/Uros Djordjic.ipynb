# %% [markdown]
# ## Deklaracija promenljivih

# %%
x = 5
y = 10

# %% [markdown]
# ## Aritmetricke operacija

# %%
add = x + y
diff = x - y
mlt = x * y
div = x / y

# %% [markdown]
# ## Prikaz rezultata

# %%
print(add)
print(diff)
print(mlt)
print(div)
# Out:
# 15
# -5
# 50
# 0.5
